# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.load("/media/sauron/GG2/datasets/deformed_blobs/case1_mnist/data/signals/sphere_C000_s000000_mnist.npy")

# %%
x.shape
# Out:
# (800,)

# %%
plt.plot(x)
